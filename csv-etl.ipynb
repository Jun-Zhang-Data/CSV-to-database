# %%
import pandas as pd
moviesData = pd.read_csv('movies.csv',index_col=False)
moviesData.head()
# Out:
#    Unnamed: 0     budget                                     genres  \
# 0           0  237000000         ['action', 'adventure', 'fantasy']
# 1           1  300000000         ['adventure', 'fantasy', 'action']
# 2           2  245000000           ['action', 'adventure', 'crime']
# 3           3  250000000               ['action', 'crime', 'drama']
# 4           4  260000000  ['action', 'adventure', 'sciencefiction']
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                     keywords original_language  \
# 0     ['cultureclash', 'future', 'spacewar']                en
# 1     ['ocean', 'drugabuse', 'exoticisland']                en
# ...

# %%
moviesData=moviesData.iloc[:,[2,5]]
moviesData=moviesData[moviesData.astype(str)['genres'] != '[]']
moviesData=moviesData[moviesData.astype(str)['keywords'] != '[]']
moviesData
# Out:
#                                          genres  \
# 0            ['action', 'adventure', 'fantasy']
# 1            ['adventure', 'fantasy', 'action']
# 2              ['action', 'adventure', 'crime']
# 3                  ['action', 'crime', 'drama']
# 4     ['action', 'adventure', 'sciencefiction']
# ...                                         ...
# 4795                                  ['drama']
# 4796    ['sciencefiction', 'drama', 'thriller']
# 4798            ['action', 'crime', 'thriller']
# 4800             ['comedy', 'drama', 'romance']
# 4802                            ['documentary']
#
#                                             keywords
# 0             ['cultureclash', 'future', 'spacewar']
# 1             ['ocean', 'drugabuse', 'exoticisland']
# 2             ['spy', 'basedonnovel', 'secretagent']
# 3          ['dccomics', 'crimefighter', 'terrorist']
# 4              ['basedonnovel', 'mars', 'medallion']
# ...                                              ...
# ...

# %%
from sqlalchemy import create_engine


mydb = MySQLdb.connect(host='localhost',
    user='root',
    passwd='')
    
cursor = mydb.cursor()
cursor.execute("CREATE DATABASE movieDB")
print("movieDB database is created")
# Out:
# movieDB database is created

# %%
from mysql.connector import Error

try:
    conn = MySQLdb.connect(host='localhost', 
                           database='movieDB', user='root', 
                           password='')
    cursor = conn.cursor()
    cursor.execute("select database();")
    record = cursor.fetchone()
    print("You're connected to database: ", record)
    cursor.execute('DROP TABLE IF EXISTS movie;')
    print('Creating table....')
    cursor.execute("CREATE TABLE movie (genres varchar(255) NOT NULL, keywords varchar(255) NOT NULL)")
    print("movie table is created....")
    for i,row in moviesData.iterrows():
        sql = "INSERT INTO movieDB.movie VALUES (%s,%s)"
        cursor.execute(sql, tuple(row))
        print("Record inserted")
        # the connection is not autocommitted by default, so we must commit to save our changes
        conn.commit()
        
except Error as e:
    print("Error while connecting to MySQL", e)
# Out:
# You're connected to database:  ('moviedb',)
# Creating table....
# movie table is created....
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# ...

# %%
# Execute query
sql = "SELECT * FROM movie"
cursor.execute(sql)

# Fetch all the records
result = cursor.fetchall()
for i in result:
    print(i)
# Out:
# ("['action', 'adventure', 'fantasy']", "['cultureclash', 'future', 'spacewar']")
# ("['adventure', 'fantasy', 'action']", "['ocean', 'drugabuse', 'exoticisland']")
# ("['action', 'adventure', 'crime']", "['spy', 'basedonnovel', 'secretagent']")
# ("['action', 'crime', 'drama']", "['dccomics', 'crimefighter', 'terrorist']")
# ("['action', 'adventure', 'sciencefiction']", "['basedonnovel', 'mars', 'medallion']")
# ("['fantasy', 'action', 'adventure']", "['dualidentity', 'amnesia', 'sandstorm']")
# ("['animation', 'family']", "['hostage', 'magic', 'horse']")
# ("['action', 'adventure', 'sciencefiction']", "['marvelcomic', 'sequel', 'superhero']")
# ("['adventure', 'fantasy', 'family']", "['witch', 'magic', 'broom']")
# ("['action', 'adventure', 'fantasy']", "['dccomics', 'vigilante', 'superhero']")
# ("['adventure', 'fantasy', 'action']", "['savingtheworld', 'dccomics', 'invulnerability']")
# ("['adventure', 'action', 'thriller']", "['killing', 'undercover', 'secretagent']")
# ...

# %%
# import the module
from sqlalchemy import create_engine
# create sqlalchemy engine
engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"  
                      .format(user="root", pw="", 
                      db="movieDB"))
# Insert whole DataFrame into MySQL
moviesData.to_sql('movie', con = engine, if_exists = 'append', chunksize = 1000,index=False)

# %%
# Execute query
sql = "SELECT * FROM movie"
cursor.execute(sql)
# Fetch all the records
result = cursor.fetchall()
for i in result:
    print(i)
# Out:
# ("['action', 'adventure', 'fantasy']", "['cultureclash', 'future', 'spacewar']")
# ("['adventure', 'fantasy', 'action']", "['ocean', 'drugabuse', 'exoticisland']")
# ("['action', 'adventure', 'crime']", "['spy', 'basedonnovel', 'secretagent']")
# ("['action', 'crime', 'drama']", "['dccomics', 'crimefighter', 'terrorist']")
# ("['action', 'adventure', 'sciencefiction']", "['basedonnovel', 'mars', 'medallion']")
# ("['fantasy', 'action', 'adventure']", "['dualidentity', 'amnesia', 'sandstorm']")
# ("['animation', 'family']", "['hostage', 'magic', 'horse']")
# ("['action', 'adventure', 'sciencefiction']", "['marvelcomic', 'sequel', 'superhero']")
# ("['adventure', 'fantasy', 'family']", "['witch', 'magic', 'broom']")
# ("['action', 'adventure', 'fantasy']", "['dccomics', 'vigilante', 'superhero']")
# ("['adventure', 'fantasy', 'action']", "['savingtheworld', 'dccomics', 'invulnerability']")
# ("['adventure', 'action', 'thriller']", "['killing', 'undercover', 'secretagent']")
# ...

# %%
# Close the connection
if (engine.connect()):
    cursor.close()
    conn.close()
    print('MySQL connection is close')
# Out:
# MySQL connection is close
